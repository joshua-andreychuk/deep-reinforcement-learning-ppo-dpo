# %%
# !python run_dpo.py
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Training SFT policy
# Evaluating SFT policy
# Return: 718.26 +/- 28.01
# Training DPO policy
# ...
#  29%|##8       | 14434/50000 [01:38<04:05, 145.16it/s]
# ...
# ...
# 100%|##########| 50000/50000 [26:34<00:00, 31.35it/s]
# OMP: Error #15: Initializing libiomp5md.dll, but found libiomp5md.dll already initialized.
# ...

# %%
# Define seeds
seeds = [123, 456, 789]

# Run DPO for each seed
for seed in seeds:
    print(f"Running DPO with seed {seed}")
    # !python run_dpo.py --seed {seed}
# Out:
# Running DPO with seed 123
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Training SFT policy
# Evaluating SFT policy
# Return: 600.42 +/- 19.54
# Training DPO policy
# Running DPO with seed 456
# ...
#  31%|###1      | 15516/50000 [01:36<03:49, 150.00it/s]
# ...
# ...
# 100%|##########| 50000/50000 [25:41<00:00, 32.45it/s]
# OMP: Error #15: Initializing libiomp5md.dll, but found libiomp5md.dll already initialized.
# ...

# %%
# !python run_dpo.py --seed 456
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Training SFT policy
# Evaluating SFT policy
# Return: 743.82 +/- 25.26
# Training DPO policy
# ...
#  32%|###1      | 15821/50000 [01:37<03:37, 157.08it/s]
# ...
# ...
# 100%|##########| 50000/50000 [26:30<00:00, 31.43it/s]
# OMP: Error #15: Initializing libiomp5md.dll, but found libiomp5md.dll already initialized.
# ...
