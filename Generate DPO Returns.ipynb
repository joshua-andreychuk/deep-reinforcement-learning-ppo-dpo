# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the scores
scores = np.load("results_dpo/Hopper-v4-dpo-seed=0/scores.npy")

# Plot the scores
plt.plot(scores)
plt.title("Training Returns Over Time")
plt.xlabel("Iterations")
plt.ylabel("Returns")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the scores
scores = np.load("results_dpo/Hopper-v4-dpo-seed=123/scores.npy")

# Plot the scores
plt.plot(scores)
plt.title("Training Returns Over Time")
plt.xlabel("Iterations")
plt.ylabel("Returns")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the scores
scores = np.load("results_dpo/Hopper-v4-dpo-seed=456/scores.npy")

# Plot the scores
plt.plot(scores)
plt.title("Training Returns Over Time")
plt.xlabel("Iterations")
plt.ylabel("Returns")
plt.show()

# %%
# !python plot.py --dpo-directory results_dpo --output results_dpo/hopper_dpo.png --seeds 0,123,456
